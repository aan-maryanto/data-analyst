# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel(r'D:\python\jupyter\kawalcovid-data.xls', sheet_name='daily_cases')
df = pd.DataFrame(data)
terbesar_sepuluh = df.sort_values(by=['Kasus Harian'], ascending=False).head(10)
terbesar_sepuluh
table = pd.pivot_table(terbesar_sepuluh, values=['Jakarta', 'Jabar', 'Jateng'], index=['Kasus Harian'], 
#                        columns=['Kasus Harian'], aggfunc=np.sum)
# table
# jakarta_df = df['Jakarta']
# jabar_df = df['Jabar']
# jateng_df = df['Jateng']
# kasus_harian = df['Kasus Harian']
# grby_tgl = df.groupby('Kasus Harian')
# avg_jakartadf = jakarta_df.mean()
# avg_jabardf = jabar_df.mean()
# avg_jatengdf = jateng_df.mean()
# sum_jakartadf = jakarta_df.sum()
# sum_jabardf = jabar_df.sum()
# sum_jatengdf = jateng_df.sum()
# grby_tgl.sum().plot.bar()
# print(grby_tgl.sum())
# plt.bar(grby_tgl)
# plt.show()
# Out:
#     Kasus Harian   Aceh   Bali  Banten  Babel  Bengkulu   DIY  Jakarta  Jambi  \
# 228   2020-10-29   34.0   59.0    91.0    5.0       9.0  82.0    713.0   31.0
# 227   2020-10-28   74.0   68.0   170.0    7.0      23.0  45.0    844.0   32.0
# 226   2020-10-27   13.0   65.0   124.0   12.0      22.0  41.0    781.0    7.0
# 225   2020-10-26   40.0   67.0   120.0    1.0       NaN  26.0    906.0    9.0
# 224   2020-10-25   87.0  109.0   231.0    4.0      26.0  44.0    771.0   22.0
# 223   2020-10-24   88.0   76.0   105.0    5.0       8.0  44.0   1062.0   26.0
# 222   2020-10-23   90.0   78.0   145.0    NaN      33.0  28.0    952.0   24.0
# 221   2020-10-22  103.0   83.0   220.0    6.0      11.0  45.0    989.0   19.0
# 220   2020-10-21   79.0   87.0   171.0   15.0       2.0  33.0   1000.0   22.0
# 219   2020-10-20   98.0   75.0    79.0    7.0      35.0  13.0    964.0   39.0
#
#      Jabar  ...  Lampung   Riau  Malut  Maluku  Papbar  Papua  Sulbar   NTT  \
# ...
