# %%
import pandas as pd

# %%
bond = pd.read_csv("D:/udemy/data-analysis-with-pandas/part_one/jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Goldfinger"]
Output None
# Out:
#   File "<ipython-input-25-e93c49aecb04>", line 2
#     Output None
#            ^
# SyntaxError: invalid syntax

# %%
bond.rename(mapper={"Goldfinger":"Gold Finger", "Sean Connery":"SeanConnery"}, axis="rows")
Output None
# Out:
#   File "<ipython-input-18-2d210dfd9386>", line 2
#     Output None
#            ^
# SyntaxError: invalid syntax

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#         Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#         Bond_Actor_Salary
# Film
# Dr. No                0.6

# %%
def convert_number_to_string(number):
    return str(number) + " millions"

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_number_to_string);
bond.head(10)
# Out:
#                        Year           Actor         Director  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen
# Casino Royale          2006    Daniel Craig  Martin Campbell
# Casino Royale          1967     David Niven       Ken Hughes
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori
# Dr. No                 1962    Sean Connery    Terence Young
# For Your Eyes Only     1981     Roger Moore        John Glen
# From Russia with Love  1963    Sean Connery    Terence Young
# GoldenEye              1995  Pierce Brosnan  Martin Campbell
# Goldfinger             1964    Sean Connery     Guy Hamilton
#
#                                              Box Office  \
# Film
# A View to a Kill       275.2 millions millions millions
# Casino Royale          581.5 millions millions millions
# Casino Royale          315.0 millions millions millions
# ...

# %%
bond = pd.read_csv("D:/udemy/data-analysis-with-pandas/part_one/jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    actor = row[1]
    budget = row[4]
    
    if actor == "Daniel Craig":
        return "The best movie ever"
    elif actor == "Roger Moore" and budget < 40:
        return "Enjoy film"
    else:
        return "I have no clue"

bond.apply(good_movie, axis="columns")
# Out:
# Film
# A View to a Kill                        I have no clue
# Casino Royale                      The best movie ever
# Casino Royale                           I have no clue
# Diamonds Are Forever                    I have no clue
# Die Another Day                         I have no clue
# Dr. No                                  I have no clue
# For Your Eyes Only                      I have no clue
# From Russia with Love                   I have no clue
# GoldenEye                               I have no clue
# Goldfinger                              I have no clue
# Licence to Kill                         I have no clue
# Live and Let Die                            Enjoy film
# Moonraker                               I have no clue
# Never Say Never Again                   I have no clue
# Octopussy                               I have no clue
# On Her Majesty's Secret Service         I have no clue
# Quantum of Solace                  The best movie ever
# ...

# %%
chicago = pd.read_csv("D:/udemy/data-analysis-with-pandas/part_one/chicago.csv").dropna(how="all")
chicago['Department'] = chicago['Department'].astype('category');

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago['Name'].str.split(",").str.get(0).value_counts().head(10)
# Out:
# WILLIAMS     293
# JOHNSON      244
# SMITH        241
# BROWN        185
# JONES        183
# RODRIGUEZ    171
# JACKSON      136
# GARCIA       130
# DAVIS        127
# HERNANDEZ    110
# Name: Name, dtype: int64

# %%
chicago['Name'].str.split(",").str.get(1).value_counts().head(10)
# Out:
#   MICHAEL J    270
#   MICHAEL      165
#   MICHAEL A    158
#   DAVID        128
#   ROBERT J     120
#   THOMAS J     120
#   ROBERT       107
#   DANIEL J     102
#   JOHN         100
#   JOSEPH        95
# Name: Name, dtype: int64

# %%
chicago[['First Name', 'Last Name']] = chicago['Name'].str.split(",", expand=True)
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary First Name      Last Name First Title Word  \
# 0              $90744.00      AARON        ELVIA J            WATER
# 1              $84450.00      AARON      JEFFERY M           POLICE
# 2              $84450.00      AARON         KARINA           POLICE
# 3              $89880.00      AARON    KIMBERLEI R            CHIEF
# 4             $106836.00    ABAD JR      VICENTE M            CIVIL
#
#        Remaining Word
# 0          RATE TAKER
# 1             OFFICER
# 2             OFFICER
# 3  CONTRACT EXPEDITER
# 4         ENGINEER IV

# %%
chicago[['First Title Word', 'Remaining Word']] = chicago['Position Title'].str.split(' ', expand=True, n=1)
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary First Name      Last Name First Title Word  \
# 0              $90744.00      AARON        ELVIA J            WATER
# 1              $84450.00      AARON      JEFFERY M           POLICE
# 2              $84450.00      AARON         KARINA           POLICE
# 3              $89880.00      AARON    KIMBERLEI R            CHIEF
# 4             $106836.00    ABAD JR      VICENTE M            CIVIL
#
#        Remaining Word
# 0          RATE TAKER
# 1             OFFICER
# 2             OFFICER
# 3  CONTRACT EXPEDITER
# 4         ENGINEER IV
