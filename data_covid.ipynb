# %%
import lux
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel(r'D:\python\jupyter\kawalcovid-data.xls', sheet_name='daily_cases')
df.fillna(value=0, inplace=True)
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.set_index("Kasus Harian", inplace=True)
df.drop(columns="?", inplace=True)

# %%
vis = df.exported[0]
vis
# Out:
# LuxWidget(current_vis={'config': {'view': {'continuousWidth': 400, 'continuousHeight': 300}, 'axis': {'labelCo…

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.fillna(value=0, inplace=True)
plt.figure(figsize=(20,10))
plt.legend(label=df.columns)
plt.plot(df)
plt.show()
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-34fb11272f47> in <module>
#       1 df.fillna(value=0, inplace=True)
#       2 plt.figure(figsize=(20,10))
# ----> 3 plt.legend(label=df.columns)
#       4 plt.plot(df)
#       5 plt.show()
#
# c:\python39\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2884 @_copy_docstring_and_deprecators(Axes.legend)
#    2885 def legend(*args, **kwargs):
# -> 2886     return gca().legend(*args, **kwargs)
#    2887
#    2888
#
# c:\python39\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     288         if len(extra_args):
#     289             raise TypeError('legend only accepts two non-keyword arguments')
# --> 290         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(df[["Jakarta","Jabar","Jateng","Jatim","Bali"]])
plt.show()
